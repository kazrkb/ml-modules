# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.metrics import mean_squared_error

# %%
hours = np.array([2,4,6,8,10]).reshape(-1,1)
marks = np.array([55,60,70,80,88])

# %%
# Train a linear model
model = LinearRegression()
model.fit(hours,marks)
# Out:
# LinearRegression()

# %%
# view learned parameters
print("m: ",model.coef_[0])
print("c:", model.intercept_)
# marks = 4.3xhours + 44.8
# Out:
# m:  4.300000000000002
# c: 44.79999999999998

# %%
# visual of the best fitted line

plt.scatter(hours, marks, color='blue', label = "Actual Data")
predicted_marks = model.predict(hours)
plt.plot(hours,predicted_marks,color="red", label = "Best fitted line")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Study hours vs marks for linear regression")
plt.legend()
plt.grid(True)
plt.show()

# %%
# predict marks for new student
new_hours = np.array([[7]])
prediction = model.predict(new_hours)
print("Predicted Marks: ",prediction[0])
# Out:
# Predicted Marks:  74.89999999999999

# %%
# compute the cost MSE
mse_lin = mean_squared_error(marks,predicted_marks)
print("MSE for LR: ", mse_lin)
# Out:
# MSE for LR:  1.5200000000000011

# %%
# Use a grdient descent based model 
sgd_reg = SGDRegressor(
    max_iter=1000,
    learning_rate="invscaling",
    eta0=0.01,
    random_state=42
)

sgd_reg.fit(hours,marks)
print("m: ",sgd_reg.coef_[0])
print("c: ",sgd_reg.intercept_)

pred_sgd = sgd_reg.predict(hours)
mse_sgd = mean_squared_error(marks,pred_sgd)
print("MSE of ")
# Out:
# m:  5.698065492806587
# c:  [34.47526543]
# MSE of
# c:\Users\rakib\anaconda3\envs\anaconda-ml-ai\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1579: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(

# %%
#Compariosn line

plt.scatter(hours, marks, label = "Actual Data")
predicted_marks = model.predict(hours)
plt.plot(hours,predicted_marks,color="red", label = "Linear Regression")
plt.plot(hours,pred_sgd,color="green", label = "SGDRegression")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("linear regression vs SGDRegression")
plt.legend()
plt.grid(True)
plt.show()
